# %%
import os
import numpy as np
import pandas as pd
import xgboost as xgb
import json
import matplotlib.pyplot as plt
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV

# Time series decomposition
#!py -m pip install stldecompose
#from stldecompose import decompose

# Chart drawing
import plotly as py
import plotly.io as pio
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

pio.renderers.default='iframe'

# Mute sklearn warnings
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
simplefilter(action='ignore', category=DeprecationWarning)

# Show charts when running kernel
# init_notebook_mode(connected=True)

# Change default background color for all visualizations
layout=go.Layout(paper_bgcolor='rgba(0,0,0,0)', plot_bgcolor='rgba(250,250,250,0.8)')
fig = go.Figure(layout=layout)
templated_fig = pio.to_templated(fig)
pio.templates['my_template'] = templated_fig.layout.template
pio.templates.default = 'my_template'

# %%
import yfinance as yf  # for downloading stock data
from pandas.api.types import is_numeric_dtype
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

dataframe = yf.download("INTC", period="max")
#print ("shape = ", dataframe.shape)
#print(dataframe.head())

# we don't need Adj Close column
dataframe = dataframe.drop(columns=['Adj Close'])

# eliminate data before 2015
dataframe['Date'] = pd.to_datetime(dataframe.index)
dataframe = dataframe[(dataframe['Date'].dt.year >= 2015)].copy()
dataframe = dataframe.set_index('Date')

# In addition to the index column called 'Date', keep a new column called Date for future use
dataframe['Date'] = pd.to_datetime(dataframe.index)

print ("shape = ", dataframe.shape)
print(dataframe.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
# shape =  (2412, 6)
#                  Open       High        Low      Close    Volume       Date
# Date
# 2015-01-02  36.669998  37.160000  36.110001  36.360001  23605600 2015-01-02
# 2015-01-05  36.200001  36.450001  35.939999  35.950001  32785000 2015-01-05
# 2015-01-06  36.080002  36.230000  35.259998  35.279999  30847600 2015-01-06
# 2015-01-07  35.639999  36.070000  35.270000  36.020000  27725200 2015-01-07
# 2015-01-08  36.369999  37.000000  36.259998  36.689999  31765400 2015-01-08

# %%
dataframe['Date'] = pd.to_datetime(dataframe['Date'], dayfirst=True)
dataframe.index = pd.to_datetime(dataframe['Date'], dayfirst=True)
dataframe.sort_index(inplace=True)

# %%
# Split input set (X) and output set (y)
X = dataframe.drop (columns=['Open'])
y = dataframe['Open']

# %%
#
# TEST 1 - Split Date into separate columns and test random times within the available range
#
# Split the data randomly into 80% Training and 20% Testing by random shuffling
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split (dataframe, test_size=0.2, shuffle=True)

# %%
#Split Date object into separate features
def date_transform(data):
    df = data.copy()
    
    df['Hour'] = df.index.hour
    df['Dayofweek'] = df.index.dayofweek
    df['Dayofmonth'] = df.index.day
    df['Dayofyear'] = df.index.dayofyear
    df['weekofyear'] = df.index.isocalendar().week
    df['Month'] = df.index.month
    df['Quarter'] = df.index.quarter
    df['Year'] = df.index.year
    
    X = df.drop(['Date', 'Open'], axis=1)
    y = df['Open']
    
    return X, y

# %%
X_train, y_train = date_transform(train_df)
X_test, y_test = date_transform(test_df)

# %%
from sklearn.ensemble import RandomForestRegressor
rfModel = RandomForestRegressor()
rfModel.fit (X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rfModel.score (X_test, y_test)
# Out:
# 0.9987910244887325

# %%
predictions = rfModel.predict(X_test)

# %%
X_test.head
# Out:
# <bound method NDFrame.head of                  High        Low      Close    Volume  Hour  Dayofweek  \
# Date
# 2019-05-20  44.520000  43.450001  43.560001  28675000     0          0
# 2019-12-19  57.990002  56.970001  57.959999  18865100     0          3
# 2021-09-13  55.490002  54.410000  54.990002  22639200     0          0
# 2017-01-31  37.369999  36.639999  36.820000  27059100     0          1
# 2020-01-16  59.840000  59.070000  59.660000  21365500     0          3
# ...               ...        ...        ...       ...   ...        ...
# 2016-01-15  30.500000  29.450001  29.760000  76373900     0          4
# 2018-07-19  52.009998  51.049999  51.980000  15954600     0          3
# 2024-07-24  32.799999  31.660000  31.700001  62216700     0          2
# 2015-12-11  34.650002  34.200001  34.270000  21251400     0          4
# 2018-10-19  45.180000  43.860001  44.000000  28368500     0          4
#
#             Dayofmonth  Dayofyear  weekofyear  Month  Quarter  Year
# Date
# 2019-05-20          20        140          21      5        2  2019
# 2019-12-19          19        353          51     12        4  2019
# 2021-09-13          13        256          37      9        3  2021
# 2017-01-31          31         31           5      1        1  2017
# 2020-01-16          16         16           3      1        1  2020
# ...                ...        ...         ...    ...      ...   ...
# 2016-01-15          15         15           2      1        1  2016
# 2018-07-19          19        200          29      7        3  2018
# 2024-07-24          24        206          30      7        3  2024
# 2015-12-11          11        345          50     12        4  2015
# 2018-10-19          19        292          42     10        4  2018
#
# [483 rows x 12 columns]>

# %%
# plot the predicted values on top of the actuals
plt.figure(figsize=(20,8))
plt.plot(X, y, label='Actual')
plt.plot(test_df[['Date']], predictions, 'ro', label='Predicted')
plt.title('1 - Forecasting with random test datetimes', weight='bold', fontsize=40);
plt.legend()

# %%
#
# TEST 2
#
# Now, train with chronological data upto 1-Jan-2020 and test with all dates after that cutoff
train_df, test_df=dataframe[dataframe.index < '2022-01-01'], dataframe[dataframe.index >= '2022-01-01']

# %%
X_train, y_train = date_transform(train_df)
X_test, y_test = date_transform(test_df)

# %%
rfModel = RandomForestRegressor()
rfModel.fit (X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rfModel.score (X_test, y_test)
# Out:
# 0.9954051914647979

# %%
predictions = rfModel.predict(X_test)

# %%
plt.close()
plt.figure(figsize=(20,8))
train_df['Open'].plot(label='Training')
test_df['Open'].plot(label='Actual')
plt.axvline('2022-01-01', color='black', ls='--')
plt.plot(test_df[['Date']], predictions, 'ro', label='Predictions')
plt.title('Random Forests - Predicting on test duration', weight='bold', fontsize=25)
plt.legend()

# %%
#
# Test 3 - Split Date into separate columns and
# train with all available data and predict for future dates
#

# %%
future = 0
future = test_df['Date'].values.copy()
len = future.size
timedelta =future[len-1]-future[0];

for index, datetime in enumerate(future):
    future[index] += timedelta;

future_df = test_df.copy(deep=True);

future_df['Date'] = future.tolist();

future_df['Date'] = pd.to_datetime(future_df['Date'], dayfirst=True)
future_df.sort_index(inplace=True)

X_train, y_train = date_transform(dataframe)
X_test, y_test = date_transform(future_df)

rfModel = RandomForestRegressor(       )
rfModel.fit (X_train, y_train)
predictions = rfModel.predict(X_test)

plt.close()
plt.figure(figsize=(20,8))
dataframe['Open'].plot(label='Train data with actual values');
#test_df['Open'].plot(label='Test data with actual values');
plt.plot(future_df['Date'].values, predictions, label='Future Predictions')
plt.title('3 - Future predictions by training with all available data range', weight='bold', fontsize=25)
plt.legend()
